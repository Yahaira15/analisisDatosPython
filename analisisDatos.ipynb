# %% [markdown]
# <a href="https://colab.research.google.com/github/Yahaira15/analisisDatosPython/blob/main/analisisDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1. IMPORTACIONES
# Se importan las librerias que se van a utilizar y el archivo que contiene los datos en este caso "actividadFisica.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv('actividadFisica.csv')
df.head()
# Out:
#      <input type="file" id="files-775385af-7316-4502-b14f-f0d6926e54ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-775385af-7316-4502-b14f-f0d6926e54ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('actividadFisica.csv')

print(data.shape)
data.head()
# Out:
# (71709, 12)
#       Periodo                          Deporte o Servicio  \
# 0  18/01/2022  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA
# 1  18/01/2022  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA
# 2  18/01/2022  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA
# 3  18/01/2022  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA
# 4  18/01/2022  CENTRO DE INICIACIÓN Y FORMACIÓN DEPORTIVA
#
#                             Nivel  Edad     Género    Etnia  \
# 0  INSCRIPCIÓN NIÑOS (7 - 8 AÑOS)     9   FEMENINO  Mestiza
# 1  INSCRIPCIÓN NIÑOS (5 - 6 AÑOS)     7   FEMENINO  Mestiza
# 2  INSCRIPCIÓN NIÑOS (6 - 7 AÑOS)    10  MASCULINO     Otro
# 3  INSCRIPCIÓN NIÑOS (6 - 7 AÑOS)     9  MASCULINO  Mestiza
# 4  INSCRIPCIÓN NIÑOS (6 - 7 AÑOS)     9   FEMENINO  Mestiza
#
#            Tipo de Poblacion           Escenario   Instructor  \
# 0  Ninguna de las anteriores  ALTO DE LOS SUEÑOS  NO ASIGNADO
# 1  Ninguna de las anteriores  ALTO DE LOS SUEÑOS  NO ASIGNADO
# ...

# %% [markdown]
# #### 2. Analisis individual de las variables
#
# Se analizaran cada una de las variables de las columnas
#
# ```
# Con data.info() podemos ver las variables categoricas
# ```

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71709 entries, 0 to 71708
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Periodo             71709 non-null  object
#  1   Deporte o Servicio  71709 non-null  object
#  2   Nivel               71709 non-null  object
#  3   Edad                71709 non-null  int64
#  4   Género              71709 non-null  object
#  5   Etnia               71709 non-null  object
#  6   Tipo de Poblacion   71709 non-null  object
#  7   Escenario           71709 non-null  object
#  8   Instructor          71709 non-null  object
#  9   Nombre del Barrio   69789 non-null  object
#  10  Municipio           71709 non-null  object
#  11  Diversidad          71709 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# #### 3. Generar graficos de las variables tipo 'categoricas'
#
# Se genera una grafica con seaborn de las variables que sean de tipo categoricas

# %%
# Se toman las variables categoricas y generamos los graficos

colCat = ['PeriodoAño', 'Deporte o Servicio', 'Nivel', 'Género',
          'Etnia', 'Tipo de Poblacion', 'Escenario', 'Instructor',
          'Nombre del Barrio', 'Municipio', 'Diversidad']

# Se transforman los datos del periodo y de fechas se pasa a años
data['PeriodoAño'] = pd.to_datetime(data['Periodo']).dt.year


fig, ax = plt.subplots(nrows=len(colCat), ncols=1, figsize=(10,75))
fig.subplots_adjust(hspace=2)


for i, col in enumerate(colCat):

#Mostrar las 10 categorias mas comunes
  top = data[col].value_counts().head(20)

  sns.barplot(x=top.index, y=top.values, ax=ax[i])
  ax[i].set_title(col)
  ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90)
# Out:
# /tmp/ipython-input-2971978229.py:8: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['PeriodoAño'] = pd.to_datetime(data['Periodo']).dt.year
# /tmp/ipython-input-2971978229.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90)
# /tmp/ipython-input-2971978229.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90)
# /tmp/ipython-input-2971978229.py:22: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=90)
# ...

# %% [markdown]
# #### ***Analisis de las graficas***
#
# Teniendo en cuenta que los datos que nos presentan son un reporte de las inscripciones hechas en diferentes periodos en el Inde Envigado, estas inscripciones son a programas de actividad fisica y deportes
#
# ---
#
# 1. Grafica de Periodo: Podemos ver que el año donde hubo mas inscripciones fue en el 2022, aunque la diferencia entre años no es mucha, así que podemos decir que las inscripciones se mantienen yaque no vemos una caida aparente de estas misma
#
# 2. Grafica de Deporte o Servicios: En la siguiente grafica solo se tomaron las diz categorias que las personas mas eligieron, podemos ver un ritmo constante en las selecciones, pero la mas elegida fue "PP zona 7", donde a pesar de que se mantiene parejos, la seleccion supera por mas de 1000 a su siguiente que es "PP zona 6", pero las que le siguen a esa categoria no tienen una diferencia muy grande
#
# 3. Nivel: En esta grafica al igual que la anterior se tomaron los diez mas seleccionado, se puede evidenciar que los tres primeros niveles son los que mas se seleccionan al momento de hacer la inscripción, "ludoteca", "musicoterapia", "hidroarebicos". Pero podemos ver que las selecciones de los niveles en las inscripciones han sido muy parejas
#
# 4.

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# #
